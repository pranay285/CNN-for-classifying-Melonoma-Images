# %%
import pandas as pd

df = pd.read_csv('train.csv')
df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0

# %%
import os
import shutil
import glob

# %%
pwd
# Out:
# 'C:\\Users\\rushi\\Documents\\BIOE'

# %%
trainImg = os.listdir('train')
for image, target in zip(df.image_name.values, df.target.values):
    if image+'.jpg' in trainImg:
        if target == 0:
            shutil.copy(os.path.join('train', image+'.jpg'), 'C:\\Users\\rushi\\Documents\\BIOE\\training\\benign')
        if target == 1:
            shutil.copy(os.path.join('train', image+'.jpg'), 'C:\\Users\\rushi\\Documents\\BIOE\\training\\malignant')

# %%
trainImg
# Out:
# ['ISIC_0015719.jpg',
#  'ISIC_0052212.jpg',
#  'ISIC_0068279.jpg',
#  'ISIC_0074268.jpg',
#  'ISIC_0074311.jpg',
#  'ISIC_0074542.jpg',
#  'ISIC_0075663.jpg',
#  'ISIC_0075914.jpg',
#  'ISIC_0076262.jpg',
#  'ISIC_0076545.jpg',
#  'ISIC_0076742.jpg',
#  'ISIC_0076995.jpg',
#  'ISIC_0077472.jpg',
#  'ISIC_0077735.jpg',
#  'ISIC_0078703.jpg',
#  'ISIC_0078712.jpg',
#  'ISIC_0079038.jpg',
#  'ISIC_0080512.jpg',
#  'ISIC_0080752.jpg',
#  'ISIC_0080817.jpg',
#  'ISIC_0081956.jpg',
#  'ISIC_0082348.jpg',
#  'ISIC_0082543.jpg',
#  'ISIC_0082934.jpg',
#  'ISIC_0083035.jpg',
#  'ISIC_0084086.jpg',
#  'ISIC_0084270.jpg',
#  'ISIC_0084395.jpg',
#  'ISIC_0085172.jpg',
#  'ISIC_0085718.jpg',
#  'ISIC_0085902.jpg',
#  'ISIC_0086349.jpg',
#  'ISIC_0086462.jpg',
#  'ISIC_0086632.jpg',
#  'ISIC_0086709.jpg',
#  'ISIC_0087290.jpg',
#  'ISIC_0087297.jpg',
#  'ISIC_0088137.jpg',
#  'ISIC_0088489.jpg',
#  'ISIC_0089401.jpg',
#  'ISIC_0089569.jpg',
#  'ISIC_0089738.jpg',
#  'ISIC_0090279.jpg',
# ...
